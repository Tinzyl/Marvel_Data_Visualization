# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
marvel_data = pd.read_csv("marvel-wikia-data.csv")

# %%
marvel_data
# Out:
#        page_id                                 name  \
# 0         1678            Spider-Man (Peter Parker)
# 1         7139      Captain America (Steven Rogers)
# 2        64786  Wolverine (James \"Logan\" Howlett)
# 3         1868    Iron Man (Anthony \"Tony\" Stark)
# 4         2460                  Thor (Thor Odinson)
# ...        ...                                  ...
# 16371   657508                   Ru'ach (Earth-616)
# 16372   665474      Thane (Thanos' son) (Earth-616)
# 16373   695217        Tinkerer (Skrull) (Earth-616)
# 16374   708811       TK421 (Spiderling) (Earth-616)
# 16375   673702                Yologarch (Earth-616)
#
#                                        urlslug                ID  \
# 0                  \/Spider-Man_(Peter_Parker)   Secret Identity
# 1            \/Captain_America_(Steven_Rogers)   Public Identity
# 2      \/Wolverine_(James_%22Logan%22_Howlett)   Public Identity
# 3        \/Iron_Man_(Anthony_%22Tony%22_Stark)   Public Identity
# 4                        \/Thor_(Thor_Odinson)  No Dual Identity
# ...                                        ...               ...
# 16371                   \/Ru%27ach_(Earth-616)  No Dual Identity
# 16372      \/Thane_(Thanos%27_son)_(Earth-616)  No Dual Identity
# 16373          \/Tinkerer_(Skrull)_(Earth-616)   Secret Identity
# 16374         \/TK421_(Spiderling)_(Earth-616)   Secret Identity
# 16375                  \/Yologarch_(Earth-616)               NaN
#
#                     ALIGN         EYE        HAIR              SEX  GSM  \
# 0         Good Characters  Hazel Eyes  Brown Hair  Male Characters  NaN
# 1         Good Characters   Blue Eyes  White Hair  Male Characters  NaN
# 2      Neutral Characters   Blue Eyes  Black Hair  Male Characters  NaN
# 3         Good Characters   Blue Eyes  Black Hair  Male Characters  NaN
# 4         Good Characters   Blue Eyes  Blond Hair  Male Characters  NaN
# ...                   ...         ...         ...              ...  ...
# 16371      Bad Characters  Green Eyes     No Hair  Male Characters  NaN
# 16372     Good Characters   Blue Eyes        Bald  Male Characters  NaN
# 16373      Bad Characters  Black Eyes        Bald  Male Characters  NaN
# 16374  Neutral Characters         NaN         NaN  Male Characters  NaN
# 16375      Bad Characters         NaN         NaN              NaN  NaN
#
#                    ALIVE  APPEARANCES FIRST APPEARANCE    Year
# 0      Living Characters       4043.0           Aug-62  1962.0
# 1      Living Characters       3360.0           Mar-41  1941.0
# 2      Living Characters       3061.0           Oct-74  1974.0
# 3      Living Characters       2961.0           Mar-63  1963.0
# 4      Living Characters       2258.0           Nov-50  1950.0
# ...                  ...          ...              ...     ...
# 16371  Living Characters          NaN              NaN     NaN
# 16372  Living Characters          NaN              NaN     NaN
# 16373  Living Characters          NaN              NaN     NaN
# 16374  Living Characters          NaN              NaN     NaN
# 16375  Living Characters          NaN              NaN     NaN
#
# [16376 rows x 13 columns]

# %%
# Drop the urlslug column
marvel_data.drop("urlslug", inplace=True, axis=1)

# %%
marvel_data.isna().sum()
# Out:
# page_id                 0
# name                    0
# ID                   3770
# ALIGN                2812
# EYE                  9767
# HAIR                 4264
# SEX                   854
# GSM                 16286
# ALIVE                   3
# APPEARANCES          1096
# FIRST APPEARANCE      815
# Year                  815
# dtype: int64

# %%
# Delete GSM column
marvel_data.drop("GSM", inplace=True, axis=1)

# %%
marvel_data.dropna(inplace=True)

# %%
marvel_data.dtypes
# Out:
# page_id               int64
# name                 object
# ID                   object
# ALIGN                object
# EYE                  object
# HAIR                 object
# SEX                  object
# ALIVE                object
# APPEARANCES         float64
# FIRST APPEARANCE     object
# Year                float64
# dtype: object

# %%
marvel_data["Year"] = marvel_data["Year"].astype("int")

# %%
marvel_data.dtypes
# Out:
# page_id               int64
# name                 object
# ID                   object
# ALIGN                object
# EYE                  object
# HAIR                 object
# SEX                  object
# ALIVE                object
# APPEARANCES         float64
# FIRST APPEARANCE     object
# Year                  int64
# dtype: object

# %%
marvel_data
# Out:
#        page_id                                               name  \
# 0         1678                          Spider-Man (Peter Parker)
# 1         7139                    Captain America (Steven Rogers)
# 2        64786                Wolverine (James \"Logan\" Howlett)
# 3         1868                  Iron Man (Anthony \"Tony\" Stark)
# 4         2460                                Thor (Thor Odinson)
# ...        ...                                                ...
# 15025   579240                         Natalie Turner (Earth-616)
# 15026   670481  Non-Newtonian Annie (Legion Personality) (Eart...
# 15027   687367              Pestilence (11th Century) (Earth-616)
# 15030   606381                         Robert Michaud (Earth-616)
# 15038   670426             Zubar (Legion Personality) (Earth-616)
#
#                      ID               ALIGN         EYE        HAIR  \
# 0       Secret Identity     Good Characters  Hazel Eyes  Brown Hair
# 1       Public Identity     Good Characters   Blue Eyes  White Hair
# 2       Public Identity  Neutral Characters   Blue Eyes  Black Hair
# 3       Public Identity     Good Characters   Blue Eyes  Black Hair
# 4      No Dual Identity     Good Characters   Blue Eyes  Blond Hair
# ...                 ...                 ...         ...         ...
# 15025   Public Identity     Good Characters  Black Eyes  Brown Hair
# 15026   Secret Identity  Neutral Characters  Green Eyes    Red Hair
# 15027   Secret Identity      Bad Characters    Red Eyes        Bald
# 15030   Secret Identity  Neutral Characters   Blue Eyes  Blond Hair
# 15038   Secret Identity  Neutral Characters  Green Eyes        Bald
#
#                      SEX                ALIVE  APPEARANCES FIRST APPEARANCE  \
# 0        Male Characters    Living Characters       4043.0           Aug-62
# 1        Male Characters    Living Characters       3360.0           Mar-41
# 2        Male Characters    Living Characters       3061.0           Oct-74
# 3        Male Characters    Living Characters       2961.0           Mar-63
# 4        Male Characters    Living Characters       2258.0           Nov-50
# ...                  ...                  ...          ...              ...
# 15025  Female Characters    Living Characters          1.0           Mar-13
# 15026  Female Characters    Living Characters          1.0           Mar-13
# 15027    Male Characters  Deceased Characters          1.0           Jun-13
# 15030    Male Characters  Deceased Characters          1.0           Jun-13
# 15038    Male Characters    Living Characters          1.0           Jan-13
#
#        Year
# 0      1962
# 1      1941
# 2      1974
# 3      1963
# 4      1950
# ...     ...
# 15025  2013
# 15026  2013
# 15027  2013
# 15030  2013
# 15038  2013
#
# [4402 rows x 11 columns]

# %%
marvel_data.isna().sum()
# Out:
# page_id             0
# name                0
# ID                  0
# ALIGN               0
# EYE                 0
# HAIR                0
# SEX                 0
# ALIVE               0
# APPEARANCES         0
# FIRST APPEARANCE    0
# Year                0
# dtype: int64

# %% [markdown]
# ## 1. Compare the number of male characters to the number of female characters on a countplot

# %%
data = marvel_data[(marvel_data["SEX"] != "Agender Characters") & (marvel_data["SEX"] != "Genderfluid Characters")]

# %%
sns.set(style="darkgrid")
plt.figure(figsize = (10,5))
ax= sns.countplot(data=data, x="SEX")
ax.set_title("Number Of Male Characters Compared To Number of Female Characters", fontsize=17)
plt.xlabel("SEX", fontsize=17)
plt.ylabel("Count", fontsize=17)
plt.yticks(size=17)
plt.xticks(size=17)
plt.show()

# %% [markdown]
# ## 2. Compare the number of times Male Characters appeared in comics to the number of times Female Characters appeared in comics

# %%
data_appearances = data.groupby("SEX")["APPEARANCES"].agg([sum])

# %%
data_appearances
# Out:
#                         sum
# SEX
# Female Characters   56521.0
# Male Characters    142829.0

# %%
data_appearances.reset_index(inplace=True)

# %%
data_appearances
# Out:
#                  SEX       sum
# 0  Female Characters   56521.0
# 1    Male Characters  142829.0

# %%
sns.set(style="darkgrid")
plt.figure(figsize = (10,5))
ax= sns.barplot(x="SEX", y="sum", data=data_appearances)
ax.set_title("Number Of Times Male Characters Appeared In Comics Compared To Number Times " 
             "Female Characters Appeared In Comics", fontsize=17)
plt.xlabel("SEX", fontsize=17)
plt.ylabel("Number Of Appearances", fontsize=17)
plt.yticks(size=17)
plt.xticks(size=17)
plt.show()

# %% [markdown]
# ## 3. Figure out if the first 10 appearances were Male Characters or Female Characters. If the gender was mixed, figure out which gender dominated for the first 10 appearances

# %%
first_10_appearances = data.sort_values(by="Year").head(10)

# %%
first_10_appearances
# Out:
#       page_id                               name                ID  \
# 901     11798         Phineas Horton (Earth-616)  No Dual Identity
# 6977   282489            Ken Masters (Earth-616)  No Dual Identity
# 1938   282586                    Zar (Earth-616)  No Dual Identity
# 60       1836  Human Torch (Android) (Earth-616)   Public Identity
# 1193   237322             David Rand (Earth-616)   Public Identity
# 2283   237826            Jim Gardley (Earth-616)   Secret Identity
# 306      1071        Thomas Halloway (Earth-616)   Public Identity
# 366      1463                  Dorma (Earth-616)  No Dual Identity
# 6979   282523        Barnabus Mullen (Earth-616)  No Dual Identity
# 735    282579            Terry Vance (Earth-616)   Public Identity
#
#                    ALIGN         EYE         HAIR                SEX  \
# 901      Good Characters   Blue Eyes   Brown Hair    Male Characters
# 6977     Good Characters  Brown Eyes   Brown Hair    Male Characters
# 1938     Good Characters  Black Eyes   Brown Hair    Male Characters
# 60       Good Characters   Blue Eyes   Blond Hair    Male Characters
# 1193     Good Characters   Blue Eyes   Blond Hair    Male Characters
# 2283     Good Characters   Blue Eyes   Black Hair    Male Characters
# 306      Good Characters  Brown Eyes   White Hair    Male Characters
# 366   Neutral Characters   Blue Eyes  Auburn Hair  Female Characters
# 6979     Good Characters   Blue Eyes         Bald    Male Characters
# 735      Good Characters   Blue Eyes  Auburn Hair    Male Characters
#
#                     ALIVE  APPEARANCES FIRST APPEARANCE  Year
# 901   Deceased Characters         41.0           Oct-39  1939
# 6977    Living Characters          3.0           Oct-39  1939
# 1938    Living Characters         18.0           Oct-39  1939
# 60      Living Characters        548.0           Oct-39  1939
# 1193    Living Characters         31.0           Oct-39  1939
# 2283    Living Characters         15.0           Oct-39  1939
# 306     Living Characters        135.0           Oct-39  1939
# 366   Deceased Characters        113.0           Oct-39  1939
# 6979    Living Characters          3.0           Jan-40  1940
# 735     Living Characters         50.0           Aug-40  1940

# %%
sns.set(style="darkgrid")
plt.figure(figsize = (10,5))
ax= sns.countplot(data=first_10_appearances, x="SEX")
ax.set_title("Gender Of First 10 Comic Appearances", fontsize=17)
plt.xlabel("SEX", fontsize=17)
plt.ylabel("Count", fontsize=17)
plt.yticks(size=17)
plt.xticks(size=17)
plt.show()

# %% [markdown]
# ## 4. Display How The Appearances in Comics for the 2 genders progressed throughout the years

# %%
appearances_years = data.groupby(["SEX", "Year"])["APPEARANCES"].agg([sum])

# %%
appearances_years
# Out:
#                           sum
# SEX               Year
# Female Characters 1939  113.0
#                   1940  263.0
#                   1941   24.0
#                   1943  153.0
#                   1944  550.0
# ...                       ...
# Male Characters   2009  586.0
#                   2010  672.0
#                   2011  772.0
#                   2012  484.0
#                   2013  445.0
#
# [141 rows x 1 columns]

# %%
appearances_years.reset_index(inplace=True)

# %%
sns.set(style="darkgrid")
plt.figure(figsize = (10,5))
ax=  sns.lineplot(x="Year", y="sum", hue="SEX", data=appearances_years)
ax.set_title("Progression Of The Number Of Appearances For Both Genders Throughout The Years", fontsize=17)
plt.xlabel("YEAR", fontsize=17)
plt.ylabel("Number Of Appearances", fontsize=17)
plt.yticks(size=17)
plt.xticks(size=17)
plt.show()

# %% [markdown]
# ## 5. Check the ALIGN attribute for both sexes

# %%
character_portrayance = data.groupby(["ALIGN", "SEX"]).count()

# %%
character_portrayance = character_portrayance.add_suffix("_Count")

# %%
character_portrayance.drop(character_portrayance.columns.difference(["page_id_Count"]), 1, inplace=True)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   """Entry point for launching an IPython kernel.

# %%
character_portrayance.rename(columns={"page_id_Count":"Count"}, inplace=True)

# %%
character_portrayance
# Out:
#                                       Count
# ALIGN              SEX
# Bad Characters     Female Characters    340
#                    Male Characters     1419
# Good Characters    Female Characters    703
#                    Male Characters     1100
# Neutral Characters Female Characters    294
#                    Male Characters      530

# %%
character_portrayance
# Out:
#                                       Count
# ALIGN              SEX
# Bad Characters     Female Characters    340
#                    Male Characters     1419
# Good Characters    Female Characters    703
#                    Male Characters     1100
# Neutral Characters Female Characters    294
#                    Male Characters      530

# %%
character_portrayance_2 = character_portrayance.reset_index()

# %%
character_portrayance_2
# Out:
#                 ALIGN                SEX  Count
# 0      Bad Characters  Female Characters    340
# 1      Bad Characters    Male Characters   1419
# 2     Good Characters  Female Characters    703
# 3     Good Characters    Male Characters   1100
# 4  Neutral Characters  Female Characters    294
# 5  Neutral Characters    Male Characters    530

# %%
sns.set(style="darkgrid")
plt.figure(figsize = (10,5))
ax= sns.barplot(x="ALIGN", y="Count", hue="SEX", data=character_portrayance_2)
ax.set_title("COUNT OF THE CHARACTERS PORTRAYED BY BOTH SEXES", fontsize=17)
plt.xlabel("SEX", fontsize=17)
plt.ylabel("Count", fontsize=17)
plt.yticks(size=17)
plt.xticks(size=17)
plt.show()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# ### Male Characters dominate in the Marvel Comics compared to Female Characters
